# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
from matplotlib import style
import seaborn as sb

# %%
df=pd.read_csv("C:\\Users\\Joovin\\OneDrive\\Documents\\age.csv")
df
# Out:
#     height  weight  gender  age
# 0     1.80   95.20    Male   27
# 1     1.85  109.30    Male   61
# 2     1.71   79.02    Male   60
# 3     1.55   74.70  Female   62
# 4     1.46   35.90  Female   58
# 5     1.58   97.10  Female   45
# 6     1.71   79.35    Male   30
# 7     1.70   73.32  Female   47
# 8     1.72   85.32    Male   40
# 9     1.46   36.00  Female   15
# 10    1.83  104.70    Male   26
# 11    1.71   79.31    Male   25
# 12    1.70   73.41    Male   35
# 13    1.58   79.70  Female   28
# 14    1.60   99.10  Female   18
# 15    1.59   75.80    Male   59
# 16    1.80   98.50    Male   50
# 17    1.62   76.30  Female   31
# 18    1.49   36.20  Female   24
# 19    1.73   83.38    Male   34

# %%
sb.barplot(x='gender',y='age',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %%
sb.barplot(x='height',y='age',data=df)
# Out:
# <Axes: xlabel='height', ylabel='age'>

# %%
df=pd.read_csv("C:\\Users\\Joovin\\OneDrive\\Documents\\age.csv")
df
# Out:
#     height  weight  gender  age
# 0     1.80   95.20    Male   27
# 1     1.85  109.30    Male   61
# 2     1.71   79.02    Male   60
# 3     1.55   74.70  Female   62
# 4     1.46   35.90  Female   58
# 5     1.58   97.10  Female   45
# 6     1.71   79.35    Male   30
# 7     1.70   73.32  Female   47
# 8     1.72   85.32    Male   40
# 9     1.46   36.00  Female   15
# 10    1.83  104.70    Male   26
# 11    1.71   79.31    Male   25
# 12    1.70   73.41  Female   35
# 13    1.58   79.70  Female   28
# 14    1.60   99.10  Female   18
# 15    1.59   75.80    Male   59
# 16    1.80   98.50    Male   50
# 17    1.62   76.30  Female   31
# 18    1.49   36.20  Female   24
# 19    1.73   83.38    Male   34

# %%
y=df.iloc[:,-2:-1]
y
# Out:
#     gender
# 0     Male
# 1     Male
# 2     Male
# 3   Female
# 4   Female
# 5   Female
# 6     Male
# 7   Female
# 8     Male
# 9   Female
# 10    Male
# 11    Male
# 12  Female
# 13  Female
# 14  Female
# 15    Male
# 16    Male
# 17  Female
# 18  Female
# 19    Male

# %%
df.plot.pie(autopct="%.1f%%");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df.plot.pie(autopct="%.1f%%")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1660, in PlotAccessor.pie(self, **kwargs)
#    1609 """
#    1610 Generate a pie plot.
#    1611
#    (...)
#    1653     >>> plot = df.plot.pie(subplots=True, figsize=(11, 6))
#    1654 """
#    1655 if (
#    1656     isinstance(self._parent, ABCDataFrame)
#    1657     and kwargs.get("y", None) is None
#    1658     and not kwargs.get("subplots", False)
#    1659 ):
# -> 1660     raise ValueError("pie requires either y column or 'subplots=True'")
#    1661 return self(kind="pie", **kwargs)
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
data = df.groupby("gender")["age"].sum()
data
# Out:
# gender
# Female    363
# Male      412
# Name: age, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df.plot.pie(autopct="%.1f%%")
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1660, in PlotAccessor.pie(self, **kwargs)
#    1609 """
#    1610 Generate a pie plot.
#    1611
#    (...)
#    1653     >>> plot = df.plot.pie(subplots=True, figsize=(11, 6))
#    1654 """
#    1655 if (
#    1656     isinstance(self._parent, ABCDataFrame)
#    1657     and kwargs.get("y", None) is None
#    1658     and not kwargs.get("subplots", False)
#    1659 ):
# -> 1660     raise ValueError("pie requires either y column or 'subplots=True'")
#    1661 return self(kind="pie", **kwargs)
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
pie, ax = plt.subplots(figsize=[10,6])
labels = data.keys()
plt.pie(x=data, autopct="%.1f%%", labels=labels, pctdistance=0.5)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b8a4ebd690>,
# ...
#  [Text(0.10906684749752493, 1.0945795643885152, 'Female'),
#   Text(-0.10906674501558969, -1.0945795746000857, 'Male')],
#  [Text(0.04957583977160224, 0.4975361656311433, '46.8%'),
#   Text(-0.0495757931889044, -0.4975361702727662, '53.2%')])

# %%
sb.jointplot(x='age',y='height',data=df)
plt.show()
# Out:
# C:\Users\Joovin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Joovin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
